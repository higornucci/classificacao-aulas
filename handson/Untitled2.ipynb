# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %%
import pandas as pd

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bff1dc1ab873> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 def load_housing_data(housing_path=HOUSING_PATH):
#       4     csv_path = os.path.join(housing_path, "housing.csv")
#       5     return pd.read_csv(csv_path)
#
# NameError: name 'HOUSING_PATH' is not defined

# %%
import os
import tarfile
from six.moves import urllib

# %%
import pandas as pd

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bff1dc1ab873> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 def load_housing_data(housing_path=HOUSING_PATH):
#       4     csv_path = os.path.join(housing_path, "housing.csv")
#       5     return pd.read_csv(csv_path)
#
# NameError: name 'HOUSING_PATH' is not defined

# %%
import pandas as pd

def load_housing_data(housing_path):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data('/home/higornucci/projetos/classificacao-aulas/input/PerguntasClassificam.csv')
housing.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-87a1db5ff9de> in <module>()
# ----> 1 housing = load_housing_data('/home/higornucci/projetos/classificacao-aulas/input/PerguntasClassificam.csv')
#       2 housing.head()
#
# <ipython-input-5-510f07af71c9> in load_housing_data(housing_path)
#       3 def load_housing_data(housing_path):
#       4     csv_path = os.path.join(housing_path, "housing.csv")
# ----> 5     return pd.read_csv(csv_path)
#
# ...

# %%
import pandas as pd

def load_housing_data(housing_path):
    csv_path = os.path.join(housing_path, "PerguntasClassificam.csv")
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data('/home/higornucci/projetos/classificacao-aulas/input')
housing.head()
# Out:
#   estabelecimento_identificador\tarea_total_destinada_confinamento\tarea_manejada_80_boa_cobertura_vegetal\tarea_manejada_20_erosao\tdispoe_de_identificacao_individual\trastreamento_sisbov\tfaz_controle_pastejo_regua_de_manejo_embrapa\tlita_trace\tapresenta_atestado_programas_controle_qualidade\tenvolvido_em_organizacao
# 0     1\tNão\tSim\tNão\tSim\tNão\tSim\tNão\tNão\tNão
# 1     2\tNão\tSim\tNão\tSim\tNão\tSim\tNão\tNão\tSim
# 2     3\tNão\tSim\tNão\tSim\tSim\tSim\tNão\tNão\tSim
# 3     4\tNão\tSim\tNão\tSim\tNão\tSim\tNão\tNão\tSim
# 4     5\tNão\tSim\tNão\tSim\tSim\tSim\tNão\tNão\tSim

# %%
import pandas as pd

def load_housing_data(housing_path):
    csv_path = os.path.join(housing_path, "PerguntasClassificam.csv")
    return pd.read_csv(csv_path, encoding='ISO-8859-1', delimiter='\t')

# %%
housing = load_housing_data('/home/higornucci/projetos/classificacao-aulas/input')
housing.head()
# Out:
#    estabelecimento_identificador area_total_destinada_confinamento  \
# 0                              1                              NÃ£o
# 1                              2                              NÃ£o
# 2                              3                              NÃ£o
# 3                              4                              NÃ£o
# 4                              5                              NÃ£o
#
#   area_manejada_80_boa_cobertura_vegetal area_manejada_20_erosao  \
# 0                                    Sim                    NÃ£o
# 1                                    Sim                    NÃ£o
# 2                                    Sim                    NÃ£o
# 3                                    Sim                    NÃ£o
# 4                                    Sim                    NÃ£o
#
#   dispoe_de_identificacao_individual rastreamento_sisbov  \
# 0                                Sim                NÃ£o
# ...

# %%
import pandas as pd

def load_housing_data(housing_path):
    csv_path = os.path.join(housing_path, "PerguntasClassificam.csv")
    return pd.read_csv(csv_path, encoding='utf-8', delimiter='\t')

housing = load_housing_data('/home/higornucci/projetos/classificacao-aulas/input')
housing.head()
# Out:
#    estabelecimento_identificador area_total_destinada_confinamento  \
# 0                              1                               Não
# 1                              2                               Não
# 2                              3                               Não
# 3                              4                               Não
# 4                              5                               Não
#
#   area_manejada_80_boa_cobertura_vegetal area_manejada_20_erosao  \
# 0                                    Sim                     Não
# 1                                    Sim                     Não
# 2                                    Sim                     Não
# 3                                    Sim                     Não
# 4                                    Sim                     Não
#
#   dispoe_de_identificacao_individual rastreamento_sisbov  \
# 0                                Sim                 Não
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 10 columns):
# estabelecimento_identificador                      1296 non-null int64
# area_total_destinada_confinamento                  1296 non-null object
# area_manejada_80_boa_cobertura_vegetal             1296 non-null object
# area_manejada_20_erosao                            1296 non-null object
# dispoe_de_identificacao_individual                 1296 non-null object
# rastreamento_sisbov                                1296 non-null object
# faz_controle_pastejo_regua_de_manejo_embrapa       1296 non-null object
# lita_trace                                         1296 non-null object
# apresenta_atestado_programas_controle_qualidade    1296 non-null object
# envolvido_em_organizacao                           1296 non-null object
# dtypes: int64(1), object(9)
# memory usage: 101.3+ KB

# %%
housing["area_total_destinada_confinamento"].value_counts()
# Out:
# Não    1291
# Sim       5
# Name: area_total_destinada_confinamento, dtype: int64

# %%
housing.describe()
# Out:
#        estabelecimento_identificador
# count                    1296.000000
# mean                     4758.476080
# std                      1901.662877
# min                         1.000000
# 25%                      4186.750000
# 50%                      5122.500000
# 75%                      6306.500000
# max                      7305.000000
